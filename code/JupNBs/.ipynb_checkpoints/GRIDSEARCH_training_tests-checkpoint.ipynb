# %% [markdown]
# # Results of the training tests

# %%
def Parse_DV_training_log(log_path):
    
    ## These are the various stats reported during training in the log file. 

    training_stats = ["train/categorical_accuracy",
                      "train/categorical_crossentropy",
                      "train/f1_het",
                      "train/f1_homalt",
                      "train/f1_homref",
                      "train/f1_macro",
                      "train/f1_micro",
                      "train/f1_weighted",
                      "train/false_negatives",
                      "train/false_positives",
                      "train/learning_rate",
                      "train/loss",
                      "train/precision",
                      "train/precision_het",
                      "train/precision_homalt",
                      "train/precision_homref",
                      "train/recall",
                      "train/recall_het",
                      "train/recall_homalt",
                      "train/recall_homref",
                      "train/true_negatives",
                      "train/true_positives"]
    
    stats_dict = {}
    stats_dict["iteration"] = []

    with open(log_path) as logs:

        for line in logs:
            
            if "train/categorical_accuracy" in line:

                line = line.split(" ")

                stats_dict["iteration"].append(int(line[4].strip("[]"))) ## record iteration

                for field in line:

                    field_id=field.split("=")[0]

                    if field_id in training_stats:
                        if field_id not in stats_dict:
                            stats_dict[field_id] = []
                        stats_dict[field_id].append(float(field.split("=")[1].strip(",").strip()))
                    
    return stats_dict

# %%
from matplotlib import pyplot as plt

# %%
help(plt.text)
# Out:
# Help on function text in module matplotlib.pyplot:
#
# text(x, y, s, fontdict=None, **kwargs)
#     Add text to the Axes.
#
#     Add the text *s* to the Axes at location *x*, *y* in data coordinates.
#
#     Parameters
#     ----------
#     x, y : float
#         The position to place the text. By default, this is in data
#         coordinates. The coordinate system can be changed using the
#         *transform* parameter.
#
#     s : str
#         The text.
#
#     fontdict : dict, default: None
#         A dictionary to override the default text properties. If fontdict
#         is None, the defaults are determined by `.rcParams`.
#
#     Returns
#     -------
#     `.Text`
#         The created `.Text` instance.
#
#     Other Parameters
#     ----------------
#     **kwargs : `~matplotlib.text.Text` properties.
#         Other miscellaneous text parameters.
#
#         Properties:
# ...

# %%
def plot_train_stat(stat, stat_dict, y_min=0.6, y_max=1):
    
    from matplotlib import pyplot as plt
    import numpy as np

    plt.figure(figsize = (10,5))
    plt.plot(stat_dict["iteration"],
             stat_dict[stat])
    
    stat_max = max(stat_dict[stat])
    plt.hlines(stat_max, min(stat_dict["iteration"]), max(stat_dict["iteration"]), color = "red", linestyle = "dashed")
    plt.text(0, stat_max+0.001, np.round(stat_max,4), color = "red")
    
    plt.ylim(y_min, y_max)
    plt.ylabel(stat)
    plt.xlabel("iteration")
    plt.show()

# %% [markdown]
# ## STEP 2

# %% [markdown]
# ### A

# %%
stats_dict_2A.keys()
# Out:
# dict_keys(['iteration', 'train/categorical_accuracy', 'train/categorical_crossentropy', 'train/f1_het', 'train/f1_homalt', 'train/f1_homref', 'train/f1_macro', 'train/f1_micro', 'train/f1_weighted', 'train/false_negatives', 'train/false_positives', 'train/learning_rate', 'train/loss', 'train/precision', 'train/precision_het', 'train/precision_homalt', 'train/precision_homref', 'train/recall', 'train/recall_het', 'train/recall_homalt', 'train/recall_homref', 'train/true_negatives', 'train/true_positives'])

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_2_training_logs/TRAIN_GRIDSEARCH_STEP_2_16194741-2.err"

stats_dict_2A= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_2A, y_min = 0.85, y_max = 0.96)

# %% [markdown]
# ### B

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_2_training_logs/TRAIN_GRIDSEARCH_STEP_2-3_concat.err"

stats_dict_2B= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_2B, y_min = 0.85, y_max = 0.96)

# %% [markdown]
# ### C

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_2_training_logs/TRAIN_GRIDSEARCH_STEP_2-4.err"

stats_dict_2C= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_2C, y_min = 0.85, y_max = 0.97)

# %% [markdown]
# ### D

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_2_training_logs/TRAIN_GRIDSEARCH_STEP_2-5.err"

stats_dict_2D= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_2D, y_min = 0, y_max = 0.96)

# %% [markdown]
# ### E

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_2_training_logs/TRAIN_GRIDSEARCH_STEP_2_16206859-6.err"

stats_dict_2E= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_2E, y_min = 0.8, y_max = 0.96)

# %% [markdown]
# ## STEP 3

# %% [markdown]
# ### A

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_4_training_logs/TRAIN_GRIDSEARCH_STEP_4_16639494-2.err"

stats_dict_4A= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_4A, y_min = 0.8, y_max = 0.96)

# %% [markdown]
# ### B

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_4_training_logs/TRAIN_GRIDSEARCH_STEP_4_16748734-3.err"

stats_dict_4B= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_4B, y_min = 0.8, y_max = 0.96)

# %% [markdown]
# ### C

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_4_training_logs/TRAIN_GRIDSEARCH_STEP_4_16748412-4.err"

stats_dict_4C= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_4C, y_min = 0.8, y_max = 0.96)

# %% [markdown]
# ### D

# %%
logfile_path = "/Users/dj20y461/Data_temp/Stickleback/FITNESS/plot_data/training_plots/NEW/Step_4_training_logs/TRAIN_GRIDSEARCH_STEP_4_16748580-5.err"

stats_dict_4D= Parse_DV_training_log(logfile_path)

# %%
plot_train_stat("train/f1_weighted", stats_dict_4D, y_min = 0.8, y_max = 0.96)

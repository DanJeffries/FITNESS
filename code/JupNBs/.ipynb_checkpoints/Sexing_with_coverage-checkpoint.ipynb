# %% [markdown]
# ### Sexing founders with coverage on the sex chromosome
#
# I output mean coverage for the genome and for the sex chromosomes (X and Y) from the test alignment to the XY genome reference. Coverage was calculated with Samtools Cov and gives chromosome wide coverage averages.
#
# I used some bash one-liners to make the file. So now I can just plot the coverage across samples. Note that I don't know the sex a priori. . . . so this is a step that I should do for the whole sample set. Though it would be nice to validate against the photos if possible.

# %%
cov_path = "../../plot_data/SC_coverage_summary_formatted_cut.tsv"

with open(cov_path) as covs:

    header = next(covs)
    
    Covdict = {}
    
    for line in covs:
        Covdict[line.split()[0]] = {}
        Covdict[line.split()[0]]["Xcov"] = float(line.split()[1])
        Covdict[line.split()[0]]["Ycov"] = float(line.split()[2])

# %%
Covdict
# Out:
# {'LG_HL_19T_372_2-3025977_S47_L001.cov': {'Xcov': 20.6481, 'Ycov': 24.8183},
#  'LG_HL_19T_384_2-3025974_S44_L001.cov': {'Xcov': 30.3791, 'Ycov': 6.89936},
#  'LG_LO_19T_222_2-3025884_S4_L001.cov': {'Xcov': 14.6498, 'Ycov': 17.8946},
#  'SL_CL_19T_365_2-3025989_S59_L001.cov': {'Xcov': 19.8801, 'Ycov': 25.7402},
#  'SL_HL_19T_228_2-3025970_S40_L001.cov': {'Xcov': 22.3414, 'Ycov': 5.4018},
#  'SL_HL_19T_290_2-3025968_S38_L001.cov': {'Xcov': 29.3228, 'Ycov': 7.16646},
#  'SL_LO_19T_186_2-3025990_S60_L001.cov': {'Xcov': 16.8744, 'Ycov': 21.0056},
#  'TL_CC_19T_115_2-3025980_S50_L001.cov': {'Xcov': 32.7012, 'Ycov': 7.50022},
#  'TL_CC_19T_117_2-3025987_S57_L001.cov': {'Xcov': 25.3588, 'Ycov': 6.71599},
#  'TL_GL_19T_212_2-3025992_S62_L001.cov': {'Xcov': 25.576, 'Ycov': 6.78266},
#  'TL_LL_19T_267_2-3025978_S48_L001.cov': {'Xcov': 18.5935, 'Ycov': 22.7871},
#  'TL_LO_19T_106_2-3025887_S7_L001.cov': {'Xcov': 14.4723, 'Ycov': 17.3342},
# ...

# %%
labels = []
cov_ratios = []

for i in Covdict:
    labels.append("_".join(i.split("_")[:4]))
    cov_ratios.append(Covdict[i]["Xcov"] / Covdict[i]["Ycov"])

# %%
cov_ratios
# Out:
# [0.8319707635091848,
#  4.403176526518402,
#  0.8186715545471819,
#  0.7723366562808369,
#  4.135917657077271,
#  4.09167148075898,
#  0.8033286361732109,
#  4.3600321057248985,
#  3.7758841213283523,
#  3.7707919901631515,
#  0.8159660509674334,
#  0.8348986396834005,
#  0.8087658151915311,
#  4.2023819091246555,
#  4.307657613711061,
#  4.0760173683177925,
#  0.8159023998910172,
#  0.8100494149217169,
#  3.923761198595906,
#  4.166244805545202,
#  3.7881877663841346,
#  3.910427993542521,
#  3.975174260798058]

# %%
from matplotlib import pyplot as plt

plt.bar(range(0,len(cov_ratios),1), cov_ratios)
plt.xticks(range(0,len(cov_ratios),1), labels, rotation = "vertical")
plt.show()
